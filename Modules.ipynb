# %%
import random

animals = ("panda", "cheetah", "tiger", "lion", "panther")

print(random.choice(animals))
# Out:
# cheetah

# %%
import math

print(math.sqrt(25))
print(math.pi)
print(math.factorial(5))
# Out:
# 5.0
# 3.141592653589793
# 120

# %%
import random

print(random.randint(50, 100))
# Out:
# 85

# %%
import random

times = int(input("How many times should I roll the dice? "))

for i in range(times):
    print(random.randint(1, 6))
# Out:
# How many times should I roll the dice?  5
# 5
# 1
# 1
# 1
# 4
