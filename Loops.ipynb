# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(5):
    print("Hello")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
count = 1

while count <= 5:
    print(count)
    count = count + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
num = 1

while num <= 5:
    if num == 3:
        break
    print(num)
    num = num + 1
# Out:
# 1
# 2

# %%
num = 0

while num < 5:
    num = num + 1

    if num == 3:
        continue

    print(num)
# Out:
# 1
# 2
# 4
# 5
