# %%
def greet():
    print("Hello!")

greet()
# Out:
# Hello!

# %%
def intro():
    print("Hello!")
    print("My name is Mehnoor.")
    print("I am learning Python.")
intro()
# Out:
# Hello!
# My name is Mehnoor.
# I am learning Python.

# %%
def welcome(name):
    print("Welcome", name)

welcome("Mehnoor")
welcome("Aman")
welcome("Sara")
# Out:
# Welcome Mehnoor
# Welcome Aman
# Welcome Sara

# %%
def double(num):
    print(num * 2)

double(4)
double(6)
# Out:
# 8
# 12

# %%
def add(a, b):
    return a + b

result = add(5, 3)
print(result)
# Out:
# 8
