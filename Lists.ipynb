# %%
colors = ["red", "blue", "green"]

colors.remove("blue")

print(colors)
# Out:
# ['red', 'green']

# %%
numbers = [10,20,30]
numbers.append(40)
print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
numbers = [1, 2, 3, 4, 5, 6]
for number in numbers:
     if number % 2==0:
         print(number)
# Out:
# 2
# 4
# 6

# %%
fruits = ["apple", "mango"]

fruits.insert(1, "banana")

print(fruits)
# Out:
# ['apple', 'banana', 'mango']
